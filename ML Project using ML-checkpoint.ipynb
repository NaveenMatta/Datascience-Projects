# %% [markdown]
# # Importing the Libraries

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from datetime import datetime, timedelta

# %% [markdown]
# # Enter the company what you want

# %%
company=input("Enter the company name ==")
# Out:
# Enter the company name == GOOG

# %% [markdown]
# # Loading the dataset

# %%
df = yf.download(company, start='2000-01-01', end=datetime.today().strftime('%Y-%m-%d'))
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Check if data was downloaded successfully

# %%
if df.empty:
    raise ValueError("No data was downloaded. Please check the ticker symbol or the date range.")

# %% [markdown]
# # Access first five rows

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.496292  897427216
# 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.694573  458857488
# 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.721690  366857939
# 2004-08-24  2.770615  2.779581  2.579581  2.611960   2.608991  306396159
# 2004-08-25  2.614201  2.689918  2.587302  2.640104   2.637103  184645512

# %% [markdown]
# # Access last five rows

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-08-07  163.240005  164.789993  160.240005  160.750000  160.750000
# 2024-08-08  162.343994  165.500000  162.029999  163.839996  163.839996
# 2024-08-09  161.645004  165.520004  160.929993  165.389999  165.389999
# 2024-08-12  165.994995  166.699997  163.550003  163.949997  163.949997
# 2024-08-13  165.184998  166.539993  164.770004  165.929993  165.929993
#
#               Volume
# Date
# 2024-08-07  19334200
# 2024-08-08  15733600
# 2024-08-09  13549200
# 2024-08-12  12435000
# 2024-08-13  12681100

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Displaying total columns from Dataset

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
for column in df.columns:
    print(column)
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %% [markdown]
# # Checking column types

# %%
df.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# # DataFrame information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5030 entries, 2004-08-19 to 2024-08-13
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5030 non-null   float64
#  1   High       5030 non-null   float64
#  2   Low        5030 non-null   float64
#  3   Close      5030 non-null   float64
#  4   Adj Close  5030 non-null   float64
#  5   Volume     5030 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 275.1 KB

# %% [markdown]
# # Checking missing values for each column

# %%
df.isna()
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2004-08-19  False  False  False  False      False   False
# 2004-08-20  False  False  False  False      False   False
# 2004-08-23  False  False  False  False      False   False
# 2004-08-24  False  False  False  False      False   False
# 2004-08-25  False  False  False  False      False   False
# ...           ...    ...    ...    ...        ...     ...
# 2024-08-07  False  False  False  False      False   False
# 2024-08-08  False  False  False  False      False   False
# 2024-08-09  False  False  False  False      False   False
# 2024-08-12  False  False  False  False      False   False
# 2024-08-13  False  False  False  False      False   False
#
# [5030 rows x 6 columns]

# %% [markdown]
# # Checking number of columns

# %%
len(df.columns)
# Out:
# 6

# %%
df.shape
# Out:
# (5030, 6)

# %% [markdown]
# # Checking missing values count on each column

# %%
df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize = (15,5))
df['Adj Close'].plot()
plt.xlabel("years")
plt.ylabel("Adj Close")
plt.title("Closing price of Google data")
# Out:
# Text(0.5, 1.0, 'Closing price of Google data')

# %%
def plot_graph(figsize, values, column_name):
    plt.figure()
    values.plot(figsize = figsize)
    plt.xlabel("years")
    plt.ylabel(column_name)
    plt.title(f"{column_name} of Google data")

# %%
for columns in df.columns:
    plot_graph((15,5),df[columns], columns)

# %% [markdown]
# # Renaming the column names

# %%
d={"Adj Close":"Adj_Close"}
df.rename(columns=d,inplace=True)

# %% [markdown]
# # Displaying all columns

# %%
for columns in df.columns:
    print(columns)
# Out:
# Open
# High
# Low
# Close
# Adj_Close
# Volume

# %% [markdown]
# # Enter only the  required column

# %%
column=input("Enter the required column==")
# Out:
# Enter the required column== Close

# %% [markdown]
# # Displaying all years

# %%
for i in range(2004,2025):
    print(i,list(df.index.year).count(i))
# Out:
# 2004 94
# 2005 252
# 2006 251
# 2007 251
# 2008 253
# 2009 252
# 2010 252
# 2011 252
# 2012 250
# 2013 252
# 2014 252
# 2015 252
# 2016 252
# 2017 251
# 2018 251
# 2019 252
# 2020 253
# 2021 252
# 2022 251
# 2023 250
# 2024 155

# %%
df['MA_for_250_days'] = df[column].rolling(250).mean()

# %%
df['MA_for_250_days'][0:250].tail()
# Out:
# Date
# 2005-08-09         NaN
# 2005-08-10         NaN
# 2005-08-11         NaN
# 2005-08-12         NaN
# 2005-08-15    5.034039
# Name: MA_for_250_days, dtype: float64

# %%
plot_graph((15,5), df[[column,'MA_for_250_days']], 'MA_for_250_days')

# %%
df['MA_for_100_days'] = df[column].rolling(100).mean()
plot_graph((15,5), df[[column,'MA_for_100_days']], 'MA_for_100_days')

# %%
plot_graph((15,5), df[[column,'MA_for_100_days', 'MA_for_250_days']], 'MA')

# %%
df['percentage_change_cp'] = df['Adj_Close'].pct_change()
df[['Adj_Close','percentage_change_cp']].head()
# Out:
#             Adj_Close  percentage_change_cp
# Date
# 2004-08-19   2.496292                   NaN
# 2004-08-20   2.694573              0.079430
# 2004-08-23   2.721690              0.010064
# 2004-08-24   2.608991             -0.041408
# 2004-08-25   2.637103              0.010775

# %%
df[['Adj_Close','percentage_change_cp']].head()
# Out:
#             Adj_Close  percentage_change_cp
# Date
# 2004-08-19   2.496292                   NaN
# 2004-08-20   2.694573              0.079430
# 2004-08-23   2.721690              0.010064
# 2004-08-24   2.608991             -0.041408
# 2004-08-25   2.637103              0.010775

# %% [markdown]
# # Enter only the  required column

# %%
column=input("Enter the required column==")
# Out:
# Enter the required column== Adj_Close

# %% [markdown]
# # Data Preparation

# %%
df = df[[column]]

# %%
column= df[[column]]

# %%
column
# Out:
#              Adj_Close
# Date
# 2004-08-19    2.496292
# 2004-08-20    2.694573
# 2004-08-23    2.721690
# 2004-08-24    2.608991
# 2004-08-25    2.637103
# ...                ...
# 2024-08-07  160.750000
# 2024-08-08  163.839996
# 2024-08-09  165.389999
# 2024-08-12  163.949997
# 2024-08-13  165.929993
#
# [5030 rows x 1 columns]

# %%
max(column),min(column)
# Out:
# ('Adj_Close', 'Adj_Close')

# %% [markdown]
# # Splitting the dataset

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df)

# %% [markdown]
# # Prepare the data for LSTM model

# %%
# Prepare the data for LSTM model
def create_dataset(data, time_step=1):
    X, Y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        Y.append(data[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 60  # Consider 60 days of historical data for predictions
X, Y = create_dataset(df_scaled, time_step)

# Reshape X to be [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Check shapes of X and Y
print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")
# Out:
# Shape of X: (4969, 60, 1)
# Shape of Y: (4969,)

# %% [markdown]
# # LSTM Model Creation

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X, Y, batch_size=64, epochs=50, verbose=1)

# Save the model (optional)
model.save('stock_prediction_model.h5')
# Out:
# C:\Users\navee\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 0.0222
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 1.7053e-04
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 1.6805e-04
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 1.6877e-04
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 1.5932e-04
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 1.9382e-04
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 1.4735e-04
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 1.5520e-04
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 1.4037e-04
# Epoch 10/50
# ...

# %%
def predict_future_prices(model, data, scaler, days_to_predict):
    predictions = []
    last_data = data[-time_step:]  # Get the last time_step days of data

    for _ in range(days_to_predict):
        input_data = last_data.reshape((1, time_step, 1))
        predicted_price = model.predict(input_data)
        predictions.append(predicted_price[0][0])
        last_data = np.append(last_data[1:], predicted_price)

    return scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Predicted price for the next day: 166.11380004882812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Predicted prices for the next week:
# [[166.1138 ]
#  [166.67372]
#  [167.15771]
#  [167.61421]
#  [168.06183]
#  [168.51064]
#  [168.96571]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ...

# %% [markdown]
# # Predicting the next day

# %%
next_day_price = predict_future_prices(model, df_scaled, scaler, 1)
print(f"Predicted price for the next day: {next_day_price[0][0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted price for the next day: 166.11380004882812

# %% [markdown]
# # Predicting next week (7 days)

# %%
next_week_prices = predict_future_prices(model, df_scaled, scaler, 7)
print("Predicted prices for the next week:")
print(next_week_prices)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Predicted prices for the next week:
# [[166.1138 ]
#  [166.67372]
#  [167.15771]
#  [167.61421]
#  [168.06183]
#  [168.51064]
#  [168.96571]]

# %% [markdown]
# # Predicting next month (30 days)

# %%
next_month_prices = predict_future_prices(model, df_scaled, scaler, 30)
print("Predicted prices for the next month:")
print(next_month_prices)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# ...

# %% [markdown]
# # Predicting next 3 month (90 days)

# %%
next_3month_prices = predict_future_prices(model, df_scaled, scaler, 90)
print("Predicted prices for the next month:")
print(next_month_prices)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ...

# %% [markdown]
# # Predicting the next year (365 days)

# %%
next_year_prices = predict_future_prices(model, df_scaled, scaler, 365)
print("Predicted prices for the next year:")
print(next_year_prices)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# ...

# %%
# Visualize the last 15 days and the predicted next week
plt.figure(figsize=(16, 8))
plt.plot(df.index[-15:], scaler.inverse_transform(df_scaled[-15:]), label='Actual Prices')
future_dates = [df.index[-1] + timedelta(days=i) for i in range(1, 8)]
plt.plot(future_dates, next_week_prices, label='Predicted Prices for Next Week', color='red')
plt.title(f'{company} Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel(f"{column.columns[0]} Price")
plt.legend()
plt.show()

# %%
# Visualize the last 60 days and the predicted next month
plt.figure(figsize=(16, 8))
plt.plot(df.index[-60:], scaler.inverse_transform(df_scaled[-60:]), label='Actual Prices')
future_dates = [df.index[-1] + timedelta(days=i) for i in range(1, 31)]
plt.plot(future_dates, next_month_prices, label='Predicted Prices for Next Month', color='red')
plt.title(f'{company} Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel(f"{column.columns[0]} Price")
plt.legend()
plt.show()

# %%
# Visualize the last 6 months and the predicted next 3 month
plt.figure(figsize=(16, 8))
plt.plot(df.index[-180:], scaler.inverse_transform(df_scaled[-180:]), label='Actual Prices')
future_dates = [df.index[-1] + timedelta(days=i) for i in range(1, 91)]
plt.plot(future_dates, next_3month_prices, label='Predicted Prices for Next 3 Month', color='red')
plt.title(f'{company} Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel(f"{column.columns[0]} Price")
plt.legend()
plt.show()

# %%
# Visualize the last 1000 days and the predicted next 1 year
plt.figure(figsize=(16, 8))
plt.plot(df.index[-1000:], scaler.inverse_transform(df_scaled[-1000:]), label='Actual Prices')
future_dates = [df.index[-1] + timedelta(days=i) for i in range(1, 366)]
plt.plot(future_dates, next_year_prices, label='Predicted Prices for Next year', color='red')
plt.title(f'{company} Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel(f"{column.columns[0]} Price")
plt.legend()
plt.show()

# %%
def predict_on_specific_date(model, data, scaler, future_date):
    days_to_predict = (future_date - datetime.today().date()).days
    if days_to_predict <= 0:
        print("Future date should be after today's date.")
        return None
    
    return predict_future_prices(model, data, scaler, days_to_predict)[-1]

# Example: Predicting the stock price on a specific date
specific_date = datetime(int(input("Enter the predicted year  ==")),int(input("Enter the predicted month ==")),int(input("Enter the predicted date  =="))).date()
predicted_price_on_date = predict_on_specific_date(model, df_scaled, scaler, specific_date)
print(f"Predicted price on {specific_date}: {predicted_price_on_date[0]}")
# Out:
# Enter the predicted year  == 2024
# Enter the predicted month == 8
# Enter the predicted date  == 13
# Future date should be after today's date.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[76], line 12
#      10 specific_date = datetime(int(input("Enter the predicted year  ==")),int(input("Enter the predicted month ==")),int(input("Enter the predicted date  =="))).date()
#      11 predicted_price_on_date = predict_on_specific_date(model, df_scaled, scaler, specific_date)
# ---> 12 print(f"Predicted price on {specific_date}: {predicted_price_on_date[0]}")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def predict_on_specific_date(model, data, scaler, future_date):
    days_to_predict = (future_date - datetime.today().date()).days
    if days_to_predict <= 0:
        print("Future date should be after today's date.")
        return None
    
    return predict_future_prices(model, data, scaler, days_to_predict)[-1]

# Example: Predicting the stock price on a specific date
specific_date = datetime(2024, 12, 31).date()
predicted_price_on_date = predict_on_specific_date(model, df_scaled, scaler, specific_date)
print(f"Predicted price on {specific_date}: {predicted_price_on_date[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# ...
